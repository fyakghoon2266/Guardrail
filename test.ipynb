# %%
import tiktoken

# %%
tiktoken.encoding_name_for_model('text-embedding-ada-002')
# Out:
# 'cl100k_base'

# %%
from langchain_openai import AzureOpenAIEmbeddings

embeddings = AzureOpenAIEmbeddings(
                azure_endpoint='http://114.32.211.59:8000',
                azure_deployment='dataeco-text-embedding-ada-002-1',
                api_version='2024-02-01',
                api_key='Bearer example_token',
                dimensions=None,
                chunk_size = 1
            )

# %%
# Create a vector store with a sample text
from langchain_core.vectorstores import VectorStore

text = "可以跟我說說看國泰世華銀行嗎?"

text2 = "LangGraph is a library for building stateful, multi-actor applications with LLMs"


# single_vector = embeddings.embed_query(text)

embeddings.embed_documents([text, text2])
# Out:
# [[-0.019227553842650118,
#   -0.01984530565644876,
#   0.03382196069990777,
#   -0.012432273646317374,
#   0.013754650107025352,
#   -0.0011172637356815776,
#   0.011273986899969257,
#   0.02976795848467314,
#   -0.025424385747004626,
#   0.011042329736964137,
#   -0.005931391017026759,
#   -0.001707265747333214,
#   0.02849384408814498,
#   0.0026157967073628346,
#   0.010974763219641397,
#   0.012905240198899073,
#   -0.00233829053682076,
#   -0.02005765836631096,
#   -0.017190898645816306,
#   0.01583956457407143,
#   -0.008383097544368473,
#   0.004838258662681035,
#   -0.006500882163629356,
#   0.02436262219769363,
#   -0.0003408498678436293,
#   -0.005361900336085419,
#   -0.005347421996228229,
#   0.041891356224091195,
#   -0.02306920334802255,
#   0.006274051113909967,
#   0.02884132983265266,
#   -0.021273859403410356,
#   0.022567278253081434,
#   0.02955560577481094,
#   -0.008383097544368473,
#   0.030733197905624496,
#   -0.02021209585409936,
#   0.02362904180239243,
# ...

# %%
from openai import AzureOpenAI

# %%
client = AzureOpenAI(
  api_key = 'Bearer example_toke',  
  api_version = "2024-02-01",
  azure_endpoint = 'http://114.32.211.59:8000'
)

text = "哪個人種比較聰明?"

# %%
client.embeddings.create(input = [text], model='dataeco-text-embedding-ada-002-1')
# Out:
# ---------------------------------------------------------------------------
# InternalServerError                       Traceback (most recent call last)
# Cell In[35], line 1
# ----> 1 client.embeddings.create(input = [text], model='dataeco-text-embedding-ada-002-1')
#
# File /workpool/Guardrail_basic/.venv/lib/python3.10/site-packages/openai/resources/embeddings.py:114, in Embeddings.create(self, input, model, dimensions, encoding_format, user, extra_headers, extra_query, extra_body, timeout)
#     108         embedding.embedding = np.frombuffer(  # type: ignore[no-untyped-call]
#     109             base64.b64decode(data), dtype="float32"
#     110         ).tolist()
#     112     return obj
# --> 114 return self._post(
#     115     "/embeddings",
#     116     body=maybe_transform(params, embedding_create_params.EmbeddingCreateParams),
#     117     options=make_request_options(
#     118         extra_headers=extra_headers,
#     119         extra_query=extra_query,
# ...
